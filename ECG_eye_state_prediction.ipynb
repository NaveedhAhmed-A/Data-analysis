# %% [markdown]
# <a href="https://colab.research.google.com/github/NaveedhAhmed-A/Data-analysis/blob/main/ECG_eye_state_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SVM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,classification_report
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/EEG_Eye_State_Classification.csv')
df
# Out:
#            AF3       F7       F3  ...       F8      AF4  eyeDetection
# 0      4329.23  4009.23  4289.23  ...  4635.90  4393.85             0
# 1      4324.62  4004.62  4293.85  ...  4632.82  4384.10             0
# 2      4327.69  4006.67  4295.38  ...  4628.72  4389.23             0
# 3      4328.72  4011.79  4296.41  ...  4632.31  4396.41             0
# 4      4326.15  4011.79  4292.31  ...  4632.82  4398.46             0
# ...        ...      ...      ...  ...      ...      ...           ...
# 14975  4281.03  3990.26  4245.64  ...  4593.33  4340.51             1
# 14976  4276.92  3991.79  4245.13  ...  4590.26  4333.33             1
# 14977  4277.44  3990.77  4246.67  ...  4591.79  4339.49             1
# 14978  4284.62  3991.79  4251.28  ...  4596.41  4350.77             1
# 14979  4287.69  3997.44  4260.00  ...  4597.95  4350.77             1
#
# [14980 rows x 15 columns]

# %%
x = df.drop('eyeDetection',axis = 1)
y = df['eyeDetection']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
model = SVC(kernel='linear')
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
acc_score = model.score(x_test,y_test)
acc_score
# Out:
# 0.6285046728971962

# %%
y = model.predict(x_test)

# %%
print(classification_report(y_test,y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.78      0.69      1586
#            1       0.65      0.46      0.54      1410
#
#     accuracy                           0.63      2996
#    macro avg       0.63      0.62      0.61      2996
# weighted avg       0.63      0.63      0.62      2996

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm = confusion_matrix(y_test,y)
cm = ConfusionMatrixDisplay(cm)
cm.plot()
plt.show()
